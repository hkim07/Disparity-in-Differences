# %%
import dispindiffs
import polars as pl
import pandas as pd
import numpy as np

# %%
iso3 = pd.read_csv("./dat/iso3.csv") # https://data.apps.fao.org/catalog/dataset/iso-3-code-list-global-region-country
iso3_to_name = dict(zip(iso3["iso3"], iso3["name"]))

df = pl.read_csv("./dat/sitc_country_country_year.csv") # https://atlas.hks.harvard.edu/data-downloads - "Country Trade by Partner"
df = df.filter(pl.col("year")>=2020)

# %%
elist = df.group_by(["country_iso3_code", "partner_iso3_code"]).agg(pl.col("export_value").sum())
elist = elist.filter(pl.col("export_value")>0)
N_T = len(set(elist["country_iso3_code"]) | set(elist["partner_iso3_code"]))
E_T = len(elist)
print(N_T, E_T)
# Out:
# 235 32296

# %%
Trade = dispindiffs.DisparityInDifferences(elist, source="country_iso3_code", target="partner_iso3_code", weight="export_value")
Trade.calc_disp()
Trade.calc_disp_in_diffs()
# Out:
# Merging bilateral relations
# Generating pre-sampled values from beta distributions
# Calculating statistical significance
# Done

# %% [markdown]
# ### Disparity Filter

# %%
n_nodes_edges_by_th = []
for th in [10**(-k) for k in np.arange(20, -0.1, -0.25)]:
    bb, th, N, E = Trade.extr_disp_backbone(th=th)    
    n_nodes_edges_by_th.append((th, N, E))
pd.DataFrame(n_nodes_edges_by_th, columns=["th", "n_nodes", "n_edges"]).to_csv("./outputs/trade_disp_info_by_th.csv", index=False)

# %%
disp_backbone, _, _, _ = Trade.extr_disp_backbone(th=0.01)

# %% [markdown]
# ### Disparity-in-Differences

# %%
n_nodes_edges_by_th = []
for th in [10**(-k) for k in np.arange(20, -0.1, -0.25)]:
    bb, th, N, E = Trade.extr_disp_in_diffs_backbone(th=th)    
    n_nodes_edges_by_th.append((th, N, E))
pd.DataFrame(n_nodes_edges_by_th, columns=["th", "n_nodes", "n_edges"]).to_csv("./outputs/trade_disp_in_diffs_info_by_th.csv", index=False)

# %%
disp_in_diffs_backbone, _, _, _  = Trade.extr_disp_in_diffs_backbone(th=0.01)

# %% [markdown]
# ### Comparisons

# %% [markdown]
# #### Top countries with respect to the number of incoming edges

# %%
top_disp = disp_backbone.group_by("target").agg(pl.len()).sort("len", descending=True)
top_disp = top_disp.with_columns(pl.col("target").replace_strict(iso3_to_name, default="").alias("name"))
print(list(top_disp["name"]))
# Out:
# ['United States of America', 'China', 'Germany', 'Netherlands', 'United Kingdom', 'India', 'Italy', 'France', 'United Arab Emirates', 'Spain', 'Republic of Korea', 'Japan', 'Poland', 'Singapore', 'Switzerland', 'Türkiye', 'Belgium', 'China, Hong Kong SAR', 'Russian Federation', 'Thailand', 'China, Taiwan Province of', 'Viet Nam', 'South Africa', 'Canada', 'Australia', 'Austria', 'Czechia', 'Brazil', 'Saudi Arabia', 'Hungary', 'Denmark', 'Indonesia', 'Malaysia', 'Romania', 'Sweden', 'Mexico', 'Greece', 'Serbia', 'Kazakhstan', 'Chile', 'Pakistan', 'Egypt', 'Iraq', 'Norway', 'Ukraine', 'Democratic Republic of the Congo', 'Mali', 'Guyana', 'Kenya', 'Zimbabwe', 'Bulgaria', 'Ireland', 'Jordan', 'Philippines', 'Guatemala', 'Trinidad and Tobago', 'New Zealand', 'Nicaragua', 'Portugal', 'Costa Rica', 'Uzbekistan', 'Peru', 'Oman', 'Burkina Faso', 'Finland', 'Honduras', 'Libya', 'Lebanon', 'Uganda', 'Slovenia', 'Panama', "Côte d'Ivoire", 'Argentina', 'Afghanistan', 'Croatia', 'Israel', 'Nigeria', 'United Republic of Tanzania', 'Bosnia and Herzegovina', 'Mozambique', 'Lithuania', 'Estonia', 'Cyprus', 'Slovakia', 'El Salvador', 'North Macedonia', 'Bangladesh', 'Gabon', 'Colombia', 'Morocco', 'Armenia', 'Namibia', 'Antigua and Barbuda', 'Suriname', 'Togo', 'Zambia', 'South Sudan', 'Bahamas', 'Kyrgyzstan', 'Malta', 'Latvia', 'Angola', 'Jamaica', 'Botswana', 'Seychelles', 'Djibouti', 'Cameroon', 'Montenegro', 'Rwanda', 'Senegal', 'Tonga', 'Ghana', 'Papua New Guinea', 'Ethiopia', 'Algeria', 'Qatar', 'Grenada', 'Madagascar', 'American Samoa', '', 'Iran (Islamic Republic of)', 'Liberia', 'Benin', 'Vanuatu', 'Nepal', 'Syrian Arab Republic', 'Dominican Republic', 'Bermuda', 'Belarus', 'Barbados', 'Saint Lucia', 'Haiti', 'Mauritius', 'Iceland', 'Georgia', 'Venezuela (Bolivarian Republic of)', 'Dominica', 'Congo', 'Somalia', 'Samoa', 'Azerbaijan', 'Kuwait', 'Palestine', 'Cayman Islands', 'Saint Vincent and the Grenadines', 'Marshall Islands', 'Cambodia', 'Guinea', 'Cuba', 'Ecuador', 'China, Macao SAR']

# %%
top_disp_in_diffs = disp_in_diffs_backbone.group_by("target").agg(pl.len()).sort("len", descending=True)
top_disp_in_diffs = top_disp_in_diffs.with_columns(pl.col("target").replace_strict(iso3_to_name, default="").alias("name"))
print(list(top_disp_in_diffs["name"]))
# Out:
# ['United States of America', 'China', 'Germany', 'India', 'Netherlands', 'United Kingdom', 'Italy', 'France', 'United Arab Emirates', 'Japan', 'Spain', 'Republic of Korea', 'Switzerland', 'Poland', 'Singapore', 'Russian Federation', 'Türkiye', 'China, Hong Kong SAR', 'Canada', 'South Africa', 'Thailand', 'China, Taiwan Province of', 'Belgium', 'Saudi Arabia', 'Australia', 'Viet Nam', 'Brazil', "Côte d'Ivoire", 'Kazakhstan', 'Iraq', 'Denmark', 'Panama', 'Sweden', 'Greece', 'Romania', 'Trinidad and Tobago', 'Jordan', 'Egypt', 'Uganda', 'Austria', 'Gabon', 'Malaysia', 'New Zealand', 'Democratic Republic of the Congo', 'Chile', 'Pakistan', 'Mexico', 'Czechia', 'Guatemala', 'Mali', 'Ireland', 'Bulgaria', 'Mozambique', 'Oman', 'Qatar', 'Libya', 'Serbia', 'Indonesia', 'Norway', 'United Republic of Tanzania', 'Senegal', 'Kenya', 'Argentina', 'Peru', 'Suriname', 'Hungary', 'Guyana', 'Ukraine', 'Armenia', 'Portugal', 'Congo', 'Israel', 'Sierra Leone', 'Bahamas', 'Lebanon', 'Madagascar', 'Colombia', 'North Macedonia', 'Burkina Faso', 'Seychelles', 'Honduras', 'South Sudan', 'Angola', 'Slovenia', 'Uzbekistan', 'Myanmar', 'Nigeria', 'Afghanistan', 'Namibia', 'Cyprus', 'Antigua and Barbuda', 'Bangladesh', 'Philippines', 'Jamaica', 'Zambia', 'Papua New Guinea', 'Belarus', 'Somalia', 'Malta', 'American Samoa', 'Haiti', 'Rwanda', 'Togo', 'Turks and Caicos Islands', 'Sri Lanka', 'Ethiopia', 'Zimbabwe', 'Croatia', 'Azerbaijan', 'Lithuania', 'Marshall Islands', 'Latvia', 'Costa Rica', 'Gibraltar', 'Guinea', 'Paraguay', 'Tonga', 'Iceland', 'Mauritius', 'Kyrgyzstan', 'Morocco', 'Nicaragua', 'Cayman Islands', 'Botswana', 'Bosnia and Herzegovina', 'Finland', 'Kuwait', 'Dominican Republic']

# %%
top_comparison = pd.DataFrame({
    "disp": list(top_disp["name"])[:30],
    "disp_in_diffs": list(top_disp_in_diffs["name"])[:30],
})
top_comparison.head(10)
# Out:
#                        disp             disp_in_diffs
# 0  United States of America  United States of America
# 1                     China                     China
# 2                   Germany                   Germany
# 3               Netherlands                     India
# 4            United Kingdom               Netherlands
# 5                     India            United Kingdom
# 6                     Italy                     Italy
# 7                    France                    France
# 8      United Arab Emirates      United Arab Emirates
# 9                     Spain                     Japan

# %% [markdown]
# #### Mexico case

# %%
disp_backbone.filter((pl.col("source")=="MEX") | (pl.col("target")=="MEX")).to_pandas().sort_values(by="source")
# Out:
#    source target         weight        sum_w_ij      p_ij  k_i_out  \
# 1     BRA    MEX    25701566153   1128768646637  0.022770      233
# 7     CHN    MEX   275781775753  12305027286532  0.022412      212
# 0     COL    MEX     5903510232    173734098745  0.033980      198
# 6     GTM    MEX     2436617412     53411621728  0.045620      179
# 4     HKG    MEX    16298635685    713205934380  0.022853      204
# 9     HND    MEX     1444977527     33820070687  0.042725      145
# 8     MEX    CAN    88035619684   2095978504153  0.042002      181
# 10    MEX    USA  1656354175473   2095978504153  0.790253      181
# 3     NIC    MEX     3094907751     27436759223  0.112802      151
# 5     TTO    MEX     1048686921     36189281870  0.028978      167
# 2     USA    MEX  1134530506321   7021600246423  0.161577      224
#
#        disp_alpha
# 1    4.778601e-03
# 7    8.372890e-03
# 0    1.102179e-03
# 6    2.457130e-04
# 4    9.159951e-03
# 9    1.858910e-03
# 8    4.421968e-04
# 10  8.036758e-123
# 3    1.596318e-08
# 5    7.586440e-03
# 2    8.555923e-18

# %%
disp_in_diffs_backbone.filter((pl.col("source")=="MEX") | (pl.col("target")=="MEX")).to_pandas().sort_values(by="source")
# Out:
#   source target  disp_in_diffs  disp_in_diffs_alpha
# 1    COL    MEX       0.028374               0.0016
# 2    GTM    MEX       0.040580               0.0000
# 3    HND    MEX       0.040785               0.0011
# 0    MEX    CAN      -0.029086               0.9970
# 5    MEX    USA       0.628676               0.0000
# 4    NIC    MEX      -0.110992               1.0000
